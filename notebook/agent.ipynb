# %%
# %pip install dotenv
# %pip install azure-identity
# %pip install agent-framework-foundry
# %pip install aiohttp

# %%
from agent_framework.foundry import FoundryAgent
from agent_framework import AgentSession, Agent, AgentRunInputs
from azure.identity.aio import AzureCliCredential
from dotenv import load_dotenv
import os

# %%
load_dotenv(override=True)

FOUNDRY_PROJECT_ENDPOINT=os.getenv('FOUNDRY_PROJECT_ENDPOINT')
FOUNDRY_AGENT_NAME=os.getenv('FOUNDRY_AGENT_NAME')
FOUNDRY_AGENT_VERSION=os.getenv('FOUNDRY_AGENT_VERSION')

# %%
agent = FoundryAgent(
            project_endpoint=FOUNDRY_PROJECT_ENDPOINT,
            agent_name=FOUNDRY_AGENT_NAME,
            agent_version=FOUNDRY_AGENT_VERSION,
            credential=AzureCliCredential()
        )

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 agent = Agent(
#       2     client=foundry_client,
#       3     name=FOUNDRY_AGENT_NAME
#       4 )
#
# File c:\github\real-time-fraud-fabric\.venv\Lib\site-packages\agent_framework\_agents.py:1697, in Agent.__init__(self, client, instructions, id, name, description, tools, default_options, context_providers, middleware, require_per_service_call_history_persistence, compaction_strategy, tokenizer, additional_properties)
#    1679 def __init__(
#    1680     self,
#    1681     client: SupportsChatGetResponse[OptionsCoT],
#    (...)   1694     additional_properties: MutableMapping[str, Any] | None = None,
#    1695 ) -> None:
#    1696     """Initialize a Agent instance."""
# -> 1697     super().__init__(
#    1698         client=client,
#    1699         instructions=instructions,
#    1700         id=id,
#    1701         name=name,
#    1702         description=description,
#    1703         tools=tools,
#    1704         default_options=default_options,
#    1705         context_providers=context_providers,
#    1706         middleware=middleware,
#    1707         require_per_service_call_history_persistence=require_per_service_call_history_persistence,
#    1708         compaction_strategy=compaction_strategy,
#    1709         tokenizer=tokenizer,
#    1710         additional_properties=additional_properties,
#    1711     )
#
# File c:\github\real-time-fraud-fabric\.venv\Lib\site-packages\agent_framework\_middleware.py:1159, in AgentMiddlewareLayer.__init__(self, middleware, *args, **kwargs)
#    1157 self._cached_agent_middleware_pipeline: AgentMiddlewarePipeline | None = None
#    1158 # Pass middleware to super so BaseAgent can store it for dynamic rebuild
# -> 1159 super().__init__(*args, middleware=middleware, **kwargs)
#
# File c:\github\real-time-fraud-fabric\.venv\Lib\site-packages\agent_framework\observability.py:1505, in AgentTelemetryLayer.__init__(self, otel_agent_provider_name, otel_provider_name, *args, **kwargs)
#    1501 """Initialize telemetry attributes and histograms."""
#    1502 self.otel_provider_name = (
#    1503     otel_agent_provider_name or otel_provider_name or getattr(self, "AGENT_PROVIDER_NAME", "unknown")
#    1504 )
# -> 1505 super().__init__(*args, **kwargs)
#    1506 self.token_usage_histogram = _get_token_usage_histogram()
#    1507 self.duration_histogram = _get_duration_histogram()
#
# File c:\github\real-time-fraud-fabric\.venv\Lib\site-packages\agent_framework\_agents.py:768, in RawAgent.__init__(self, client, instructions, id, name, description, tools, default_options, context_providers, middleware, require_per_service_call_history_persistence, compaction_strategy, tokenizer, additional_properties)
#     766 self.default_options = {k: v for k, v in self.default_options.items() if v is not None}
#     767 self._async_exit_stack = AsyncExitStack()
# --> 768 self._update_agent_name_and_description()
#
# File c:\github\real-time-fraud-fabric\.venv\Lib\site-packages\agent_framework\_agents.py:842, in RawAgent._update_agent_name_and_description(self)
#     840 update_fn = getattr(self.client, "_update_agent_name_and_description", None)
#     841 if callable(update_fn):
# --> 842     update_fn(self.name, self.description)
#
# TypeError: RawAgent._update_agent_name_and_description() takes 1 positional argument but 3 were given
